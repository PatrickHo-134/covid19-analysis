# %% [markdown]
# With your application, please include the following coding samples using the data from https://github.com/CSSEGISandData/COVID-19:
#
# 1. Python: Download a timeseries of daily deaths per country
#
# 2. Python: Convert the table so that each country and each day is a separate row
#
# 3.  Python: Provide code to upload the table from step 3 into an SQL table named deaths_total
#
# 4.  Python: From the data in step 2, calculate the daily change in deaths for each country
#
# 5.  Python: Provide code to upload the table from step 4 into an SQL table named deaths_change_python
#
# 6. SQL: Provide SQL code to calculate the daily change for each country using only the data from deaths_total and save it into an SQL table named deaths_change_sql

# %%
from __future__ import print_function
import pandas as pd
import pymysql
# from sqlalchemy import create_engine
from datetime import date, datetime, timedelta

user='root'
password='Phatxitho!304'
host='localhost'
database='covid19'

# %% [markdown]
# # step 1

# %%
# download a timeseries of daily deaths per country
us_case = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv"
us_death = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv"

glob_cases = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv"
glob_death = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv"
glob_recov = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv"

cases = pd.read_csv(glob_cases)
deaths = pd.read_csv(glob_death)
recov = pd.read_csv(glob_recov)

# %% [markdown]
# # step 2

# %%
# convert the table to appropriate format
def convert_df(df):
    df = df.drop(['Long', 'Lat'], axis=1)
    df = df.melt(id_vars=['Province/State', 'Country/Region'], var_name='date', value_name='total')
    df.date = pd.to_datetime(df.date)
    df['Province/State'].fillna('all', inplace=True)
    df.total.fillna(0, inplace=True)
    df.columns = ['prov_state','country_region','date','total']
    
    return df

# %%
# convert the table so that each country and each day is a separate row
cases = convert_df(cases)
deaths = convert_df(deaths)
recov = convert_df(recov)

dates = deaths['date'].dt.floor('D')
dates = deaths['date'].dt.date

newDeath = deaths.drop(['prov_state'], axis=1)
newDeath = newDeath.groupby(['country_region', dates]).sum().reset_index()
# newDeath

# %%
# newDeath.date[0].to_datetime()
# datetime(newDeath.date[0].strftime("%d-%m-%Y"))
# newDeath.date[0].strftime("%d-%m-%Y")

# deaths.sort_values(['total'], ascending=False)
# newDeath[newDeath['country_region']=='Australia']

# %%
# first approach
# sqlEngine = create_engine('mysql+pymysql://root:Phatxitho!304@localhost/covid19', pool_recycle=3600)
# conn = sqlEngine.connect()

# second approach
# conn = pymysql.connect(user=user,password=password, host=host, database=database)
# cursor= conn.cursor()
# conn.close()

# %% [markdown]
# # step 3

# %%
# query to create deaths_total tabla
create_deathTotal = "CREATE TABLE IF NOT EXISTS `deaths_total` (`CountryRegion` varchar(16) NOT NULL, `CalDate` date NOT NULL, `Total` int(11) NOT NULL, PRIMARY KEY (`CountryRegion`, `CalDate`))"
                    
# insert query
insert_deathTotal = "INSERT IGNORE INTO `deaths_total` (`CountryRegion`, `CalDate`, `Total`) VALUES (%s, %s, %s)"

# select deaths_total
select_deathTotal = "SELECT * FROM `deaths_total`"

# %%
conn = pymysql.connect(user=user,password=password, host=host, database=database)

try:
    cursor = conn.cursor()
    
    # create deaths_total table
    cursor.execute(create_deathTotal)
    
    for i, row in newDeath.iterrows():
        cursor.execute(insert_deathTotal, (row[0], row[1].strftime("%Y-%m-%d"), int(row[2])))
        conn.commit()
finally:
    conn.close()
# Out:
# C:\Users\phath\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\pymysql\cursors.py:170: Warning: (1050, "Table 'deaths_total' already exists")
#   result = self._query(query)
# C:\Users\phath\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'Afghanistan-2020-01-22' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\phath\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'Afghanistan-2020-01-23' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\phath\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'Afghanistan-2020-01-24' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\phath\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'Afghanistan-2020-01-25' for key 'PRIMARY'")
# ...

# %%
conn = pymysql.connect(user=user,password=password, host=host, database=database)

try:
    cursor = conn.cursor()
    # select 
    cursor.execute(select_deathTotal)
    data = cursor.fetchall()
finally:
    conn.close()

# %% [markdown]
# # step 4: calculate the daily change in deaths for each country

# %%
change = []
countries = newDeath.country_region.unique()

# calcualte change for each country
for country in countries:
    country_change = list(newDeath[newDeath['country_region'] == country].total.diff(periods=1))
    change += country_change
    
newDeath['daily_change'] = change
newDeath['daily_change'].fillna(0, inplace=True)

# %% [markdown]
# # step 5: Provide code to upload the table from step 4 into an SQL table named deaths_change_python

# %%
# query to create deaths_total tabla
create_deathChange = """CREATE TABLE IF NOT EXISTS `deaths_change_python` 
(`CountryRegion` varchar(16) NOT NULL,
`CalDate` date NOT NULL,
`Total` int(11) NOT NULL,
`DailyChange` int(11) NOT NULL,
PRIMARY KEY (`CountryRegion`, `CalDate`))"""
                    
# insert query
insert_deathChange = "INSERT IGNORE INTO `deaths_change_python` (`CountryRegion`, `CalDate`, `Total`, `DailyChange`) VALUES (%s, %s, %s, %s)"

# select deaths_total
select_deathChange = "SELECT * FROM `deaths_change_python`"

# %%
conn = pymysql.connect(user=user,password=password, host=host, database=database)

try:
    cursor = conn.cursor()
    
    # create deaths_change_python table
    cursor.execute(create_deathChange)
    
    for i, row in newDeath.iterrows():
        cursor.execute(insert_deathChange, (row[0], row[1].strftime("%Y-%m-%d"), int(row[2]), int(row[3])))
        conn.commit()
finally:
    conn.close()

# %% [markdown]
# # step 6: SQL: Provide SQL code to calculate the daily change for each country using only the data from deaths_total and save it into an SQL table named deaths_change_sql

# %%
newDeath[newDeath.country_region == "Australia"]
# Out:
#     country_region        date  total  daily_change
# 576      Australia  2020-01-22      0           0.0
# 577      Australia  2020-01-23      0           0.0
# 578      Australia  2020-01-24      0           0.0
# 579      Australia  2020-01-25      0           0.0
# 580      Australia  2020-01-26      0           0.0
# ..             ...         ...    ...           ...
# 643      Australia  2020-03-29     16           2.0
# 644      Australia  2020-03-30     17           1.0
# 645      Australia  2020-03-31     18           1.0
# 646      Australia  2020-04-01     20           2.0
# 647      Australia  2020-04-02     24           4.0
#
# [72 rows x 4 columns]

# %%
# sqlalchemy approach
try:
    frame = newDeath.to_sql(name='deaths_total', con=conn, if_exists='fail', schema='covid19');
except ValueError as vx:
    print(vx)
except Exception as ex:   
    print(ex)
else:
    print("Table %s created successfully."%tableName);   
finally:
    conn.close()
# Out:
# Execution failed on sql 'SELECT name FROM sqlite_master WHERE type='table' AND name=?;': not all arguments converted during string formatting

# %%
config = {
  'user': 'root',
  'password': 'Phatxitho!304',
  'host': 'localhost',
    'port':'3306',
  'database': 'covid19',
  'raise_on_warnings': True
}

cnx = mysql.connector.connect(**config)
cursor = cnx.cursor()

DB_NAME = 'covid19'

TABLES = {}
TABLES['deaths_total'] = (
    "CREATE TABLE `deaths_total` IF NOT EXIST"
    "  `country_region` varchar(16) NOT NULL,"
    "  `date` date NOT NULL,"
    "  `total` int(11) NOT NULL,"
    "  PRIMARY KEY (`country_region`,`date`)"
    ") ENGINE=InnoDB"
)

for table_name in TABLES:
    table_description = TABLES[table_name]
    try:
        print("Creating table {}: ".format(table_name), end='')
        cursor.execute(table_description)
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
            print("already exists.")
        else:
            print(err.msg)
    else:
        print("OK")

cursor.close()
cnx.close()
# Out:
# Creating table deaths_total: OK
